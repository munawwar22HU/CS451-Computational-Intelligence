# %%
import copy
import json
import math
import random
import sys
import numpy as np

from PIL import Image
from PIL import ImageDraw
from PIL import ImageFilter

COLOUR_BLACK = (0, 0, 0, 255)
COLOUR_WHITE = (255, 255, 255, 255)
POLY_MIN_POINTS = 3
POLY_MAX_POINTS = 5
POLYGONS = 50
class Shape(object):
    def __init__(self, colour=None, points=[]):
        self.colour = colour
        self.points = points

    def mutate(self, size):
        rand = random.random()
        if rand <= 0.5:
            idx = random.randrange(0, 4)
            value = random.randrange(0, 256)
            colour = list(self.colour)
            colour[idx] = value
            self.colour = tuple(colour)
        else:
            idx = random.randrange(0, len(self.points))
            point = rand_point(size[0], size[1])
            self.points[idx] = point

class Chromosome(object):
    def __init__(self, imageSize, shapes=[]):
        self.imageSize = imageSize
        self.shapes = shapes
        self.generation = 0
    
    def __iter__(self):
        for shape in self.shapes:
            yield shape
    
    def __getitem__(self, idx):
        if idx < len(self.shapes):
            return self.shapes[idx]
        else:
            raise IndexError

    def draw(self, background=COLOUR_BLACK, show=False, save=False,
             generation=None):
        size = self.imageSize
        img = Image.new('RGB', size, background)
        draw = Image.new('RGBA', size)
        pdraw = ImageDraw.Draw(draw)
        for shape in self.shapes:
            colour = shape.colour
            points = shape.points
            pdraw.polygon(points, fill=colour, outline=colour)
            img.paste(draw, mask=draw)

        if show:
            img.show()

        if save:
            fileName = u"{}".format(generation)
            saveLoc = u"{}.png".format(fileName)
            img = img.filter(ImageFilter.GaussianBlur(radius=3))
            img.save(saveLoc)

        return img

    def crossOver(self):
        shapes = copy.deepcopy(self.shapes)
        rand = random.randrange(0, len(shapes))
        newShape = shapes[rand]
        newShape.mutate(self.imageSize)
        return Chromosome(self.imageSize, shapes)

def fitness(img1, img2):
    img1List = np.frombuffer(img1.tobytes(), dtype=np.uint8)
    img1List = img1List.reshape((img1.size[1], img1.size[0], 3)) /255
    img2List = np.frombuffer(img2.tobytes(), dtype=np.uint8)
    img2List = img2List.reshape((img2.size[1], img2.size[0], 3)) /255
    difference = np.absolute(img1List - img2List) 
    difference = np.sum(difference,axis=(0,1))
    fitness = math.sqrt((difference[0]*difference[0])+(difference[1]*difference[1])+(difference[2]*difference[2]))
    return fitness

def rand_point(width, height):
    x = random.randrange(0 - 10, width + 10, 1)
    y = random.randrange(0 - 10, height + 10, 1)
    return (x, y)

def rand_color():
    red = random.randrange(0, 256)
    green = random.randrange(0, 256)
    blue = random.randrange(0, 256)
    alpha = random.randrange(0, 256)
    return (red, green, blue, alpha)

def initiateChromosome(imageSize, chromosomeSize=50, fixed_colour=False):
    chromosome = None
    shapes = []
    (width, height) = imageSize

    for i in range(POLYGONS):
        pointNo = random.randrange(POLY_MIN_POINTS, POLY_MAX_POINTS + 1)
        points = []
        for j in range(pointNo):
            point = rand_point(width, height)
            points.append(point)
        colour = COLOUR_WHITE if fixed_colour else rand_color()
        shape = Shape(colour, points)
        shapes.append(shape)
    chromosome = Chromosome(imageSize, shapes)
    return chromosome

# %%
path = "mona1.jpeg"
img = Image.open(path)
imageSize = img.size
chromosome = initiateChromosome(imageSize, chromosomeSize=POLYGONS, fixed_colour=True)
parent = chromosome.draw(show=False)
parentFitness = fitness(img, parent)

generations = imageNo = 0
while True:
    mutatedChromosome = chromosome.crossOver()
    child = mutatedChromosome.draw()
    fitness_child = fitness(img, child)
    if fitness_child < parentFitness:
        chromosome = mutatedChromosome
        parentFitness = fitness_child
        # print("picking child w. fitness: {}".format(fitness_child))

    generations += 1
    if generations % 100 == 0:
        print("showing generation {}".format(generations))
        imageNo += 1
        chromosome.draw(show=True, save=True, generation=imageNo)
# Out:
# showing generation 100
# showing generation 200
# showing generation 300
# showing generation 400
# showing generation 500
# showing generation 600
# showing generation 700
# showing generation 800
# showing generation 900
# showing generation 1000
# showing generation 1100
# showing generation 1200
# showing generation 1300
# showing generation 1400
# showing generation 1500
# showing generation 1600
# showing generation 1700
# showing generation 1800
# showing generation 1900
# showing generation 2000
# showing generation 2100
# showing generation 2200
# showing generation 2300
# showing generation 2400
# showing generation 2500
# showing generation 2600
# showing generation 2700
# showing generation 2800
# showing generation 2900
# showing generation 3000
# showing generation 3100
# showing generation 3200
# showing generation 3300
# showing generation 3400
# showing generation 3500
# showing generation 3600
# showing generation 3700
# showing generation 3800
# showing generation 3900
# showing generation 4000
# showing generation 4100
# showing generation 4200
# showing generation 4300
# showing generation 4400
# showing generation 4500
# showing generation 4600
# showing generation 4700
# showing generation 4800
# showing generation 4900
# showing generation 5000
# showing generation 5100
# showing generation 5200
# showing generation 5300
# showing generation 5400
# showing generation 5500
# showing generation 5600
# showing generation 5700
# showing generation 5800
# showing generation 5900
# showing generation 6000
# showing generation 6100
# showing generation 6200
# showing generation 6300
# showing generation 6400
# showing generation 6500
# showing generation 6600
# showing generation 6700
# showing generation 6800
# showing generation 6900
# showing generation 7000
# showing generation 7100
# showing generation 7200
# showing generation 7300
# showing generation 7400
# showing generation 7500
# showing generation 7600
# showing generation 7700
# showing generation 7800
# showing generation 7900
# showing generation 8000
# showing generation 8100
# showing generation 8200
# showing generation 8300
# showing generation 8400
# showing generation 8500
# showing generation 8600
# showing generation 8700
# showing generation 8800
# showing generation 8900
# showing generation 9000
# showing generation 9100
# showing generation 9200
# showing generation 9300
# showing generation 9400
# showing generation 9500
# showing generation 9600
# showing generation 9700
# showing generation 9800
# showing generation 9900
# showing generation 10000
# showing generation 10100
# showing generation 10200
# showing generation 10300
# showing generation 10400
# showing generation 10500
# showing generation 10600
# showing generation 10700
# showing generation 10800
# showing generation 10900
# showing generation 11000
# showing generation 11100
# showing generation 11200
# showing generation 11300
# showing generation 11400
# showing generation 11500
# showing generation 11600
# showing generation 11700
# showing generation 11800
# showing generation 11900
# showing generation 12000
# showing generation 12100
# showing generation 12200
# showing generation 12300
# showing generation 12400
# showing generation 12500
# showing generation 12600
# showing generation 12700
# showing generation 12800
# showing generation 12900
# showing generation 13000
# showing generation 13100
# showing generation 13200
# showing generation 13300
# showing generation 13400
# showing generation 13500
# showing generation 13600
# showing generation 13700
# showing generation 13800
# showing generation 13900
# showing generation 14000
# showing generation 14100
# showing generation 14200
# showing generation 14300
# showing generation 14400
# showing generation 14500
# showing generation 14600
# showing generation 14700
# showing generation 14800
# showing generation 14900
# showing generation 15000
# showing generation 15100
# showing generation 15200
# showing generation 15300
# showing generation 15400
# showing generation 15500
# showing generation 15600
# showing generation 15700
# showing generation 15800
# showing generation 15900
# showing generation 16000
# showing generation 16100
# showing generation 16200
# showing generation 16300
# showing generation 16400
# showing generation 16500
# showing generation 16600
# showing generation 16700
# showing generation 16800
# showing generation 16900
# showing generation 17000
# showing generation 17100
# showing generation 17200
# showing generation 17300
# showing generation 17400
# showing generation 17500
# showing generation 17600
# showing generation 17700
# showing generation 17800
# showing generation 17900
# showing generation 18000
# showing generation 18100
# showing generation 18200
# showing generation 18300
# showing generation 18400
# showing generation 18500
# showing generation 18600
# showing generation 18700
# showing generation 18800
# showing generation 18900
# showing generation 19000
# showing generation 19100
# showing generation 19200
# showing generation 19300
# showing generation 19400
# showing generation 19500
# showing generation 19600
# showing generation 19700
# showing generation 19800
# showing generation 19900
# showing generation 20000
# showing generation 20100
# showing generation 20200
# showing generation 20300
# showing generation 20400
# showing generation 20500
# showing generation 20600
# showing generation 20700
# showing generation 20800
# showing generation 20900
# showing generation 21000
# showing generation 21100
# showing generation 21200
# showing generation 21300
# showing generation 21400
# showing generation 21500
# showing generation 21600
# showing generation 21700
# showing generation 21800
# showing generation 21900
# showing generation 22000
# showing generation 22100
# showing generation 22200
# showing generation 22300
# showing generation 22400
# showing generation 22500
# showing generation 22600
# showing generation 22700
# showing generation 22800
# showing generation 22900
# showing generation 23000
# showing generation 23100
# showing generation 23200
# showing generation 23300
# showing generation 23400
# showing generation 23500
# showing generation 23600
# showing generation 23700
# showing generation 23800
# showing generation 23900
# showing generation 24000
# showing generation 24100
# showing generation 24200
# showing generation 24300
# showing generation 24400
# showing generation 24500
# showing generation 24600
# showing generation 24700
# showing generation 24800
# showing generation 24900
# showing generation 25000
# showing generation 25100
# showing generation 25200
# showing generation 25300
# showing generation 25400
# showing generation 25500
# showing generation 25600
# showing generation 25700
# showing generation 25800
# showing generation 25900
# showing generation 26000
# showing generation 26100
# showing generation 26200
# showing generation 26300
# showing generation 26400
# showing generation 26500
# showing generation 26600
# showing generation 26700
# showing generation 26800
# showing generation 26900
# showing generation 27000
# showing generation 27100
# showing generation 27200
# showing generation 27300
# showing generation 27400
# showing generation 27500
# showing generation 27600
# showing generation 27700
# showing generation 27800
# showing generation 27900
# showing generation 28000
# showing generation 28100
# showing generation 28200
# showing generation 28300
# showing generation 28400
# showing generation 28500
# showing generation 28600
# showing generation 28700
# showing generation 28800
# showing generation 28900
# showing generation 29000
# showing generation 29100
# showing generation 29200
# showing generation 29300
# showing generation 29400
# showing generation 29500
# showing generation 29600
# showing generation 29700
# showing generation 29800
# showing generation 29900
# showing generation 30000
# showing generation 30100
# showing generation 30200
# showing generation 30300
# showing generation 30400
# showing generation 30500
# showing generation 30600
# showing generation 30700
# showing generation 30800
# showing generation 30900
# showing generation 31000
# showing generation 31100
# showing generation 31200
# showing generation 31300
# showing generation 31400
# showing generation 31500
# showing generation 31600
# showing generation 31700
# showing generation 31800
# showing generation 31900
# showing generation 32000
# showing generation 32100
# showing generation 32200
# showing generation 32300
# showing generation 32400
# showing generation 32500
# showing generation 32600
# showing generation 32700
# showing generation 32800
# showing generation 32900
# showing generation 33000
# showing generation 33100
# showing generation 33200
# showing generation 33300
# showing generation 33400
# showing generation 33500
# showing generation 33600
# showing generation 33700
# showing generation 33800
# showing generation 33900
# showing generation 34000
# showing generation 34100
# showing generation 34200
# showing generation 34300
# showing generation 34400
# showing generation 34500
# showing generation 34600
# showing generation 34700
# showing generation 34800
# showing generation 34900
# showing generation 35000
# showing generation 35100
# showing generation 35200
# showing generation 35300
# showing generation 35400
# showing generation 35500
# showing generation 35600
# showing generation 35700
# showing generation 35800
# showing generation 35900
# showing generation 36000
# showing generation 36100
# showing generation 36200
# showing generation 36300
# showing generation 36400
# showing generation 36500
# showing generation 36600
# showing generation 36700
# showing generation 36800
# showing generation 36900
# showing generation 37000
# showing generation 37100
# showing generation 37200
# showing generation 37300
# showing generation 37400
# showing generation 37500
# showing generation 37600
# showing generation 37700
# showing generation 37800
# showing generation 37900
# showing generation 38000
# showing generation 38100
# showing generation 38200
# showing generation 38300
# showing generation 38400
# showing generation 38500
# showing generation 38600
# showing generation 38700
# showing generation 38800
# showing generation 38900
# showing generation 39000
# showing generation 39100
# showing generation 39200
# showing generation 39300
# showing generation 39400
# showing generation 39500
# showing generation 39600
# showing generation 39700
# showing generation 39800
# showing generation 39900
# showing generation 40000
# showing generation 40100
# showing generation 40200
# showing generation 40300
# showing generation 40400
# showing generation 40500
# showing generation 40600
# showing generation 40700
# showing generation 40800
# showing generation 40900
# showing generation 41000
# showing generation 41100
# showing generation 41200
# showing generation 41300
# showing generation 41400
# showing generation 41500
# showing generation 41600
# showing generation 41700
# showing generation 41800
# showing generation 41900
# showing generation 42000
# showing generation 42100
# showing generation 42200
# showing generation 42300
# showing generation 42400
# showing generation 42500
# showing generation 42600
# showing generation 42700
# showing generation 42800
# showing generation 42900
# showing generation 43000
# showing generation 43100
# showing generation 43200
# showing generation 43300
# showing generation 43400
# showing generation 43500
# showing generation 43600
# showing generation 43700
# showing generation 43800
# showing generation 43900
# showing generation 44000
# showing generation 44100
# showing generation 44200
# showing generation 44300
# showing generation 44400
# showing generation 44500
# showing generation 44600
# showing generation 44700
# showing generation 44800
# showing generation 44900
# showing generation 45000
# showing generation 45100
# showing generation 45200
# showing generation 45300
# showing generation 45400
# showing generation 45500
# showing generation 45600
# showing generation 45700
# showing generation 45800
# showing generation 45900
# showing generation 46000
# showing generation 46100
# showing generation 46200
# showing generation 46300
# showing generation 46400
# showing generation 46500
# showing generation 46600
# showing generation 46700
# showing generation 46800
# showing generation 46900
# showing generation 47000
# showing generation 47100
# showing generation 47200
# showing generation 47300
# showing generation 47400
# showing generation 47500
# showing generation 47600
# showing generation 47700
# showing generation 47800
# showing generation 47900
# showing generation 48000
# showing generation 48100
# showing generation 48200
# showing generation 48300
# showing generation 48400
# showing generation 48500
# showing generation 48600
# showing generation 48700
# showing generation 48800
# showing generation 48900
# showing generation 49000
# showing generation 49100
# showing generation 49200
# showing generation 49300
# showing generation 49400
# showing generation 49500
# showing generation 49600
# showing generation 49700
# showing generation 49800
# showing generation 49900
# showing generation 50000
# showing generation 50100
# showing generation 50200
# showing generation 50300
# showing generation 50400
# showing generation 50500
# showing generation 50600
# showing generation 50700
# showing generation 50800
# showing generation 50900
# showing generation 51000
# showing generation 51100
# showing generation 51200
# showing generation 51300
# showing generation 51400
# showing generation 51500
# showing generation 51600
# showing generation 51700
# showing generation 51800
# showing generation 51900
# showing generation 52000
# showing generation 52100
# showing generation 52200
# showing generation 52300
# showing generation 52400
# showing generation 52500
# showing generation 52600
# showing generation 52700
# showing generation 52800
# showing generation 52900
# showing generation 53000
# showing generation 53100
# showing generation 53200
# showing generation 53300
# showing generation 53400
# showing generation 53500
# showing generation 53600
# showing generation 53700
# showing generation 53800
# showing generation 53900
# showing generation 54000
# showing generation 54100
# showing generation 54200
# showing generation 54300
# showing generation 54400
# showing generation 54500
# showing generation 54600
# showing generation 54700
# showing generation 54800
# showing generation 54900
# showing generation 55000
# showing generation 55100
# showing generation 55200
# showing generation 55300
# showing generation 55400
# showing generation 55500
# showing generation 55600
# showing generation 55700
# showing generation 55800
# showing generation 55900
# showing generation 56000
# showing generation 56100
# showing generation 56200
# showing generation 56300
# showing generation 56400
# showing generation 56500
# showing generation 56600
# showing generation 56700
# showing generation 56800
# showing generation 56900
# showing generation 57000
# showing generation 57100
# showing generation 57200
# showing generation 57300
# showing generation 57400
# showing generation 57500
# showing generation 57600
# showing generation 57700
# showing generation 57800
# showing generation 57900
# showing generation 58000
# showing generation 58100
# showing generation 58200
# showing generation 58300
# showing generation 58400
# showing generation 58500
# showing generation 58600
# showing generation 58700
# showing generation 58800
# showing generation 58900
# showing generation 59000
# showing generation 59100
# showing generation 59200
# showing generation 59300
# showing generation 59400
# showing generation 59500
# showing generation 59600
# showing generation 59700
# showing generation 59800
# showing generation 59900
# showing generation 60000
# showing generation 60100
# showing generation 60200
# showing generation 60300
# showing generation 60400
# showing generation 60500
# showing generation 60600
# showing generation 60700
# showing generation 60800
# showing generation 60900
# showing generation 61000
# showing generation 61100
# showing generation 61200
# showing generation 61300
# showing generation 61400
# showing generation 61500
# showing generation 61600
# showing generation 61700
# showing generation 61800
# showing generation 61900
# showing generation 62000
# showing generation 62100
# showing generation 62200
# showing generation 62300
# showing generation 62400
# showing generation 62500
# showing generation 62600
# showing generation 62700
# showing generation 62800
# showing generation 62900
# showing generation 63000
# showing generation 63100
# showing generation 63200
# showing generation 63300
# showing generation 63400
# showing generation 63500
# showing generation 63600
# showing generation 63700
# showing generation 63800
# showing generation 63900
# showing generation 64000
# showing generation 64100
# showing generation 64200
# showing generation 64300
# showing generation 64400
# showing generation 64500
# showing generation 64600
# showing generation 64700
# showing generation 64800
# showing generation 64900
# showing generation 65000
# showing generation 65100
# showing generation 65200
# showing generation 65300
# showing generation 65400
# showing generation 65500
# showing generation 65600
# showing generation 65700
# showing generation 65800
# showing generation 65900
# showing generation 66000
# showing generation 66100
# showing generation 66200
# showing generation 66300
# showing generation 66400
# showing generation 66500
# showing generation 66600
# showing generation 66700
# showing generation 66800
# showing generation 66900
# showing generation 67000
# showing generation 67100
# showing generation 67200
# showing generation 67300
# showing generation 67400
# showing generation 67500
# showing generation 67600
# showing generation 67700
# showing generation 67800
# showing generation 67900
# showing generation 68000
# showing generation 68100
# showing generation 68200
# showing generation 68300
# showing generation 68400
# showing generation 68500
# showing generation 68600
# showing generation 68700
# showing generation 68800
# showing generation 68900
# showing generation 69000
# showing generation 69100
# showing generation 69200
# showing generation 69300
# showing generation 69400
# showing generation 69500
# showing generation 69600
# showing generation 69700
# showing generation 69800
# showing generation 69900
# showing generation 70000
# showing generation 70100
# showing generation 70200
# showing generation 70300
# showing generation 70400
# showing generation 70500
# showing generation 70600
# showing generation 70700
# showing generation 70800
# showing generation 70900
# showing generation 71000
# showing generation 71100
# showing generation 71200
